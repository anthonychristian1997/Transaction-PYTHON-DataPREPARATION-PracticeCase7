# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/Anthony Christian/Desktop/Transactions Data/transactions.csv',low_memory = False,sep=';')

# %%
df.head()
# Out:
#    transaction_id  accountNumber  customerId  creditLimit availableMoney  \
# 0         5533441      733493772   733493772         5000         5000.0
# 1         5533442      733493772   733493772         5000        4888.67
# 2         5533443      733493772   733493772         5000        4863.92
# 3         5533444      733493772   733493772         5000        4676.52
# 4         5533445      733493772   733493772         5000        4449.18
#
#    transactionDateTime transactionAmount merchantName acqCountry  \
# 0  2016-01-08T19:04:50            111.33         Lyft         US
# 1  2016-01-09T22:32:39             24.75         Uber         US
# 2  2016-01-11T13:36:55             187.4         Lyft         US
# 3  2016-01-11T22:47:46            227.34         Lyft         US
# 4  2016-01-16T01:41:11               0.0         Lyft         US
#
#   merchantCountryCode  ...  isFraud  echoBuffer currentBalance merchantCity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641914 entries, 0 to 641913
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   transaction_id            641914 non-null  int64
#  1   accountNumber             641914 non-null  int64
#  2   customerId                641914 non-null  int64
#  3   creditLimit               641914 non-null  int64
#  4   availableMoney            641914 non-null  object
#  5   transactionDateTime       641914 non-null  object
#  6   transactionAmount         641914 non-null  object
#  7   merchantName              641914 non-null  object
#  8   acqCountry                638001 non-null  object
#  9   merchantCountryCode       641290 non-null  object
#  10  posEntryMode              638569 non-null  float64
#  11  posConditionCode          641627 non-null  float64
#  12  merchantCategoryCode      641914 non-null  object
# ...

# %%
df.dtypes
# Out:
# transaction_id                int64
# accountNumber                 int64
# customerId                    int64
# creditLimit                   int64
# availableMoney               object
# transactionDateTime          object
# transactionAmount            object
# merchantName                 object
# acqCountry                   object
# merchantCountryCode          object
# posEntryMode                float64
# posConditionCode            float64
# merchantCategoryCode         object
# currentExpDate               object
# accountOpenDate              object
# dateOfLastAddressChange      object
# cardCVV                       int64
# enteredCVV                    int64
# cardLast4Digits               int64
# transactionType              object
# isFraud                        bool
# echoBuffer                  float64
# currentBalance               object
# merchantCity                float64
# merchantState               float64
# merchantZip                 float64
# ...

# %%
#Transform Data Types

#Transform Numerical
df['transactionAmount'] = pd.to_numeric(df['transactionAmount'],errors='coerce')
df['availableMoney'] = pd.to_numeric(df['availableMoney'],errors='coerce')
df['currentBalance'] = pd.to_numeric(df['currentBalance'],errors='coerce')

#Transform Date Time
df['transactionDateTime'] = pd.to_datetime(df['transactionDateTime'], format="%Y-%m-%dT%H:%M:%S")

# %%
df.isnull().sum()
# Out:
# transaction_id                   0
# accountNumber                    0
# customerId                       0
# creditLimit                      0
# availableMoney                 279
# transactionDateTime              0
# transactionAmount             1816
# merchantName                     0
# acqCountry                    3913
# merchantCountryCode            624
# posEntryMode                  3345
# posConditionCode               287
# merchantCategoryCode             0
# currentExpDate                   0
# accountOpenDate                  0
# dateOfLastAddressChange          0
# cardCVV                          0
# enteredCVV                       0
# cardLast4Digits                  0
# transactionType                589
# isFraud                          0
# echoBuffer                  641914
# currentBalance                 120
# merchantCity                641914
# merchantState               641914
# merchantZip                 641914
# cardPresent                      0
# ...

# %%
#Fill Missing Value

df['availableMoney'].fillna(df['availableMoney'].median(),inplace = True)
df['transactionAmount'].fillna(df['transactionAmount'].median(),inplace = True)
df['acqCountry'].fillna(df['acqCountry'].mode()[0],inplace = True)
df['merchantCategoryCode'].fillna(df['merchantCategoryCode'].mode()[0],inplace = True)
df['transactionType'].fillna(df['transactionType'].mode()[0],inplace = True)
df['posEntryMode'].fillna(df['posEntryMode'].mode()[0],inplace = True)

# %%
df.isnull().sum()
# Out:
# transaction_id                   0
# accountNumber                    0
# customerId                       0
# creditLimit                      0
# availableMoney                   0
# transactionDateTime              0
# transactionAmount                0
# merchantName                     0
# acqCountry                       0
# merchantCountryCode            624
# posEntryMode                     0
# posConditionCode               287
# merchantCategoryCode             0
# currentExpDate                   0
# accountOpenDate                  0
# dateOfLastAddressChange          0
# cardCVV                          0
# enteredCVV                       0
# cardLast4Digits                  0
# transactionType                  0
# isFraud                          0
# echoBuffer                  641914
# currentBalance                 120
# merchantCity                641914
# merchantState               641914
# merchantZip                 641914
# cardPresent                      0
# ...

# %%
df.describe()
# Out:
#        transaction_id  accountNumber    customerId    creditLimit  \
# count    6.419140e+05   6.419140e+05  6.419140e+05  641914.000000
# mean     5.854398e+06   5.547701e+08  5.547701e+08   10697.210608
# std      1.853048e+05   2.546884e+08  2.546884e+08   11460.359133
# min      5.533441e+06   1.005471e+08  1.005471e+08     250.000000
# 25%      5.693919e+06   3.223192e+08  3.223192e+08    5000.000000
# 50%      5.854398e+06   5.438879e+08  5.438879e+08    7500.000000
# 75%      6.014876e+06   7.862277e+08  7.862277e+08   15000.000000
# max      6.175354e+06   9.999853e+08  9.999853e+08   50000.000000
#
#        availableMoney  transactionAmount   posEntryMode  posConditionCode  \
# count   641914.000000      641914.000000  641914.000000     641627.000000
# mean      6654.155469         135.396502       9.114905          3.238367
# std       9226.427265         146.909332      16.919556          9.680862
# min      -1244.930000           0.000000       2.000000          1.000000
# ...

# %% [markdown]
# # Data Selection

# %%
df[['accountNumber','customerId','creditLimit']].head()
# Out:
#    accountNumber  customerId  creditLimit
# 0      733493772   733493772         5000
# 1      733493772   733493772         5000
# 2      733493772   733493772         5000
# 3      733493772   733493772         5000
# 4      733493772   733493772         5000

# %%
df.iloc[0]
# Out:
# transaction_id                          5533441
# accountNumber                         733493772
# customerId                            733493772
# creditLimit                                5000
# availableMoney                             5000
# transactionDateTime         2016-01-08 19:04:50
# transactionAmount                        111.33
# merchantName                               Lyft
# acqCountry                                   US
# merchantCountryCode                          US
# posEntryMode                                  5
# posConditionCode                              1
# merchantCategoryCode                  rideshare
# currentExpDate                       01/04/2020
# accountOpenDate                      03/08/2014
# dateOfLastAddressChange              03/08/2014
# cardCVV                                     492
# enteredCVV                                  492
# cardLast4Digits                            9184
# transactionType                        PURCHASE
# ...

# %%
#Filter data Fraud and Not

Fraud = df[df['isFraud']==True]

Valid = df[df['isFraud']==False]

# %% [markdown]
# # Pivoting

# %%
data = df[df['transactionType']=='PURCHASE']
pd.pivot_table(data,index = ['merchantCategoryCode','merchantCountryCode'],values = 'transactionAmount',aggfunc = 'mean').head(11)
# Out:
#                                           transactionAmount
# merchantCategoryCode merchantCountryCode
# airline              CAN                         120.453043
#                      MEX                         178.147949
#                      PR                          136.571667
#                      US                          148.468147
# auto                 CAN                         143.973704
#                      MEX                         172.448085
#                      PR                          205.022105
#                      US                          149.723503
# cable/phone          CAN                         140.793750
#                      MEX                         102.668462
#                      US                           98.246807

# %% [markdown]
# # CrossTab

# %%
pd.crosstab(df.merchantCategoryCode, df.posEntryMode, margins=True)
# Out:
# posEntryMode             2.0     5.0     9.0   80.0   90.0     All
# merchantCategoryCode
# airline                 2473    4007    3032    212    266    9990
# auto                    2535    4124    3035    194    259   10147
# cable/phone              298     592     536     19     45    1490
# entertainment          17395   28002   20565   1428   1748   69138
# fastfood               25214   41015   30440   2010   2517  101196
# food                   17168   27490   20490   1396   1701   68245
# food_delivery           1365    1956    1571      0     98    4990
# fuel                    5483    8965    7009    449    660   22566
# furniture               1905    3228    2314    166    200    7813
# gym                      869    1103     691     38    173    2874
# health                  3479    5940    4269    287    369   14344
# hotels                  5666    9288    6894    453    578   22879
# mobileapps              3694    5933    4344    290    353   14614
# ...

# %% [markdown]
# # Categorical Encoding (Nominal Data)

# %%
df = pd.get_dummies(df, columns=['transactionType'])

# %%
df.head(8)
# Out:
#    transaction_id  transactionType_ADDRESS_VERIFICATION  \
# 0         5533441                                     0
# 1         5533442                                     0
# 2         5533443                                     0
# 3         5533444                                     0
# 4         5533445                                     1
# 5         5533446                                     0
# 6         5533447                                     0
# 7         5533448                                     1
#
#    transactionType_PURCHASE  transactionType_REVERSAL
# 0                         1                         0
# 1                         1                         0
# 2                         1                         0
# 3                         1                         0
# 4                         0                         0
# 5                         1                         0
# 6                         1                         0
# ...

# %% [markdown]
# # Categorical Data (Ordinal Data)

# %%
bins = [0, 250, 500, 750, 1000, 2000]
labels =['very low','low','moderate','high spending','very-high']
df['transactionLevel'] = pd.cut(df['transactionAmount'], bins,labels=labels)
df[['transactionAmount','transactionLevel']].head(8)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Phyton\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'transactionAmount'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-3e374659034d> in <module>
#       1 bins = [0, 250, 500, 750, 1000, 2000]
# ...

# %%
bins = [0, 250, 500, 750, 1000, 2000]
labels =['very low','low','moderate','high spending','very-high']
df['transactionLevel'] = pd.cut(df['transactionAmount'], bins,labels=labels)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Phyton\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'transactionAmount'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-60278df77b30> in <module>
#       1 bins = [0, 250, 500, 750, 1000, 2000]
# ...

# %%
df.transactionLevel.fillna(df['transactionLevel'].mode()[0],inplace = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-c948c7873270> in <module>
# ----> 1 df.transactionLevel.fillna(df['transactionLevel'].mode()[0],inplace = True)
#
# C:\Phyton\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'transactionLevel'

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["transactionLevelchanged"] = le.fit_transform(df["transactionLevel"])
df.head(7)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Phyton\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'transactionLevel'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-4f80aed4ebc3> in <module>
# ...

# %%
df["transactionLevelnew"] = df['transactionLevel'].map({'very low':0,'low':1,'moderate':2,'high spending':3,'very-high':4})
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Phyton\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'transactionLevel'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-390199fc93d3> in <module>
# ...
